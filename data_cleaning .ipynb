# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import emoji
import pandas as pd
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from textblob import TextBlob

# %% [markdown]
# ## Reading the CSV

# %%
df =  pd.read_csv('reviews_data.csv')

# %%
df
# Out:
#                     Review                                           Comments  \
# 0             Does the job                                               Good
# 1                Must buy!                                            Awesome
# 2                   Super!                                    Superb Phone ❤️
# 3                Excellent              Best phone.. Picture quality ossam...
# 4          Value-for-money                                 Camera quality gud
# ...                    ...                                                ...
# 1602  Good quality product  best in fast charging, battery backup , displa...
# 1603           Pretty good                                           Good one
# 1604             Wonderful                               Worthy of the price.
# 1605             Just wow!                               Superb quality phone
# 1606               Awesome                        Awesome phone In this price
#
#       Ratings                    Locations              Cuctomers  \
# 0           3             Jajapur District          Prakash Sethy
# 1           5         Murshidabad District  Sabyasachee Mukherjee
# 2           5                    Rampurhat             Souvik Dey
# 3           5                     Konnagar      Flipkart Customer
# 4           4   Udham Singh Nagar District         Subrat Vishwas
# ...       ...                          ...                    ...
# 1602        5                         Pune      Flipkart Customer
# 1603        4                    Bengaluru        Anu Rose George
# 1604        5                        Udgir      Flipkart Customer
# 1605        5       East Godavari District             Narayana R
# 1606        5                    Faridabad         Jamwant Maurya
#
#               Time
# 0              NaN
# 1     8 months ago
# 2     8 months ago
# 3     8 months ago
# 4     8 months ago
# ...            ...
# 1602  2 months ago
# 1603  2 months ago
# 1604  2 months ago
# 1605  2 months ago
# 1606  2 months ago
#
# [1607 rows x 6 columns]

# %%
df.head(20)
# Out:
#                    Review                                           Comments  \
# 0            Does the job                                               Good
# 1               Must buy!                                            Awesome
# 2                  Super!                                    Superb Phone ❤️
# 3               Excellent              Best phone.. Picture quality ossam...
# 4         Value-for-money                                 Camera quality gud
# 5               Fabulous!                                    Just go for it🤩
# 6               Fabulous!                                   Nice product...🔥
# 7    Good quality product                            Camera quality too good
# 8   Mind-blowing purchase  Excellent phone, smooth ui, great sound, aweso...
# 9               Just wow!           I am so happy happy this mobile phone 🔥🔥
# 10              Just wow!                 Very nice phone, camera very good.
# 11     Highly recommended   Very much satisfied with this Redmi note 12pro..
# 12   Good quality product  I am writing this review after 12 days of usag...
# 13       Perfect product!  I will say that you can go with this beast bes...
# 14       Perfect product!  The phone runs very smoothly, the main camera ...
# 15              Must buy!  The feeL yoU are Going to have when yoau get t...
# 16    Best in the market!                                   Go for this one.
# 17           Does the job  Overall I'm happy with the phone's performance...
# 18       Perfect product!  One of the best camera, even in low lightFull ...
# 19  Mind-blowing purchase  i am saurabh thank you redmi ❤️redmi mobile th...
#
#     Ratings                    Locations              Cuctomers          Time
# 0         3             Jajapur District          Prakash Sethy           NaN
# 1         5         Murshidabad District  Sabyasachee Mukherjee  8 months ago
# 2         5                    Rampurhat             Souvik Dey  8 months ago
# 3         5                     Konnagar      Flipkart Customer  8 months ago
# 4         4   Udham Singh Nagar District         Subrat Vishwas  8 months ago
# 5         5                   Aurangabad      Flipkart Customer  7 months ago
# 6         5         Pudukkottai District       Dinesh Thangappa  7 months ago
# 7         4                      Varkala         Pravitha Sunny  8 months ago
# 8         5                        Surat                    Lav  8 months ago
# 9         5                       Alandi      Flipkart Customer  8 months ago
# 10        5                    Faridabad      Flipkart Customer           NaN
# 11        5                     Sainthia      Flipkart Customer  8 months ago
# 12        4                    Bardhaman           Kuntal Kundu  8 months ago
# 13        5                    Baleshwar      Flipkart Customer  7 months ago
# 14        5                       Jhansi               saif ali  7 months ago
# 15        5                     Akaltara           SHIVJEET DAS  7 months ago
# 16        5                  Barrackpore        Debasmita Nandy  7 months ago
# 17        3                    Kozhikode       Rahul Poovachery  7 months ago
# 18        5                   Vijayawada   Flipkart SHAIK USMAN  7 months ago
# 19        5                    Begusarai          Saurabh Kumar  6 months ago

# %% [markdown]
# ## Createing a function for Removing Emojis

# %%
def remove_emojis(text):
    return emoji.get_emoji_regexp().sub(r'', text)

# %% [markdown]
# ## Downloading NLTK Resources ,Creating Output DataFrame,Analyzing Sentiment,Iterating Over Rows and Building the Output DataFrame

# %%
# Download stopwords
nltk.download('stopwords')
nltk.download('vader_lexicon')
nltk.download('punkt')

# Load stopwords
stop_words = set(stopwords.words('english'))

# Initialize sentiment analyzer
vader = SentimentIntensityAnalyzer()

# Define regex pattern to match unwanted characters
pattern = r'[^A-Za-z\s]+'
output_df = pd.DataFrame(columns=["Review", "Comments", "Ratings","Times","Locations","Positive_Score", "Negative_Score", "Neutral_Score", "Sentiment", "Subjectivity_Score"])

def analyze_sentiment(text):
    # Apply regex to remove unwanted characters
    cleaned_text = re.sub(r'[^a-zA-Z\s]', '', text)

    # Tokenize text into words
    words = word_tokenize(cleaned_text)

    # Remove stopwords and lowercase
    words = [word.lower() for word in words if word.lower() not in stop_words]

    # Join words back into cleaned text
    cleaned_text = ' '.join(words)

    # Get polarity scores for cleaned text using VADER
    vader_scores = vader.polarity_scores(cleaned_text)
    compound_score = vader_scores["compound"]

    # To get the subjectivity scores using TextBlob
    blob = TextBlob(cleaned_text)
    polarity_score = blob.sentiment.polarity
    subjectivity_score = blob.sentiment.subjectivity

    return compound_score, polarity_score, subjectivity_score

# Analyze sentiment for each row (combining Review and Comments)
for index, row in df.iterrows():
    review_text = str(row["Review"])  
    comments_text = str(row["Comments"])
    ratings = row["Ratings"]
    Locations = row["Locations"]
    Cuctomers = row["Cuctomers"]
    Time = str(row["Time"])
    

    # Analyze sentiment for the combined text of review and comments
    compound_score, polarity_score, subjectivity_score = analyze_sentiment(review_text + ' ' + comments_text)

    # Calculate Negative_Score and Neutral_Score
    if compound_score < 0:
        negative_score = -compound_score
        neutral_score = 0
    elif compound_score == 0:
        negative_score = 0
        neutral_score = 0
    else:
        negative_score = 0
        neutral_score = compound_score

    # Append results to output dataframe
    new_row = {
        "Review": review_text,
        "Comments": comments_text,
        "Ratings": ratings,
        "Locations" : Locations,
        "Cuctomers" : Cuctomers,
        "Time" : Time,
        "Positive_Score": compound_score,
        "Negative_Score": negative_score,
        "Neutral_Score": neutral_score,
        "Sentiment": "Positive" if compound_score > 0 else ("Neutral" if compound_score == 0 else "Negative"),
        "Subjectivity_Score": subjectivity_score
    }

    output_df = pd.concat([output_df, pd.DataFrame([new_row])], ignore_index=True)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Removing Emojis from Review and Comments

# %%
# Apply the function to 'Review' and 'Comments' columns
output_df['Review'] = output_df['Review'].apply(remove_emojis)
output_df['Comments'] = output_df['Comments'].apply(remove_emojis)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_5308\675994836.py:2: DeprecationWarning: 'emoji.get_emoji_regexp()' is deprecated and will be removed in version 2.0.0. If you want to remove emoji from a string, consider the method emoji.replace_emoji(str, replace='').
# To hide this warning, pin/downgrade the package to 'emoji~=1.6.3'
#   return emoji.get_emoji_regexp().sub(r'', text)
# C:\Users\admin\AppData\Local\Temp\ipykernel_5308\675994836.py:2: DeprecationWarning: 'emoji.get_emoji_regexp()' is deprecated and will be removed in version 2.0.0. If you want to remove emoji from a string, consider the method emoji.replace_emoji(str, replace='').
# To hide this warning, pin/downgrade the package to 'emoji~=1.6.3'
#   return emoji.get_emoji_regexp().sub(r'', text)

# %%
output_df.head(5)
# Out:
#             Review                               Comments Ratings Times  \
# 0     Does the job                                   Good       3   NaN
# 1        Must buy!                                Awesome       5   NaN
# 2           Super!                          Superb Phone        5   NaN
# 3        Excellent  Best phone.. Picture quality ossam...       5   NaN
# 4  Value-for-money                     Camera quality gud       4   NaN
#
#                      Locations  Positive_Score Negative_Score  Neutral_Score  \
# 0             Jajapur District          0.4404              0         0.4404
# 1         Murshidabad District          0.6249              0         0.6249
# 2                    Rampurhat          0.8402              0         0.8402
# 3                     Konnagar          0.8360              0         0.8360
# 4   Udham Singh Nagar District          0.0000              0         0.0000
#
#   Sentiment  Subjectivity_Score              Cuctomers          Time
# 0  Positive            0.600000          Prakash Sethy           nan
# 1  Positive            1.000000  Sabyasachee Mukherjee  8 months ago
# 2  Positive            0.833333             Souvik Dey  8 months ago
# 3  Positive            0.650000      Flipkart Customer  8 months ago
# 4   Neutral            0.000000         Subrat Vishwas  8 months ago

# %% [markdown]
# ## Storing output_df into into another csv file

# %%
column_names = ['Review', 'Comments', 'Ratings', 'Locations', 'Time', 'Positive_Score', 'Negative_Score', 'Neutral_Score', 'Sentiment', 'Subjectivity_Score']

selected_columns = output_df[column_names]

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#             Review                               Comments  Ratings  \
# 1        Must buy!                                Awesome        5
# 2           Super!                        Superb Phone ❤️        5
# 3        Excellent  Best phone.. Picture quality ossam...        5
# 4  Value-for-money                     Camera quality gud        4
# 5        Fabulous!                        Just go for it🤩        5
#
#                      Locations              Cuctomers          Time
# 1         Murshidabad District  Sabyasachee Mukherjee  8 months ago
# 2                    Rampurhat             Souvik Dey  8 months ago
# 3                     Konnagar      Flipkart Customer  8 months ago
# 4   Udham Singh Nagar District         Subrat Vishwas  8 months ago
# 5                   Aurangabad      Flipkart Customer  7 months ago

# %%
selected_columns.to_csv("sentiment_analysis_results.csv", index=False)
